# %% [markdown]
# <a href="https://colab.research.google.com/github/Bads171222/PCVK_Ganjil_2026/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan Matplotlib?
# Jawab
# Tanpa cmap, gambar grayscale dapat ditampilkan dengan warna default. Dengan cmap="gray", gambar ditampilkan dalam gradasi hitam-putih.
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# Jawab
# int16 menggunakan memori lebih kecil daripada int32. Keduanya tetap menghasilkan gambar hitam karena semua nilai pixel adalah 0.
#
# 3. Apakah kegunaan from google.colab.patches import cv2_imshow pada potongan kode berikut?
# Jawab
# Digunakan untuk menampilkan gambar menggunakan OpenCV di Google Colab.
#
# 4. Apakah kegunaan from skimage import io pada potongan kode soal nomor 3?
# Jawab
# Digunakan untuk membaca, menampilkan, dan menyimpan gambar menggunakan library Scikit-image.

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/PCVK2026/BMW M4.jpg")
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/PCVK2026/BMW M4.jpg")
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# plt.show()

img_gray = cv2.imread("/content/drive/MyDrive/PCVK2026/BMW M4.jpg", cv2.IMREAD_GRAYSCALE)

plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title("Tanpa Cmap")

plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Dengan Cmap")

plt.show()

imgRGB=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgRGBsmall=cv2.resize(imgRGB,(400,250))
plt.imshow(imgRGBsmall)

imgBalik=cv2.flip(imgRGBsmall,1)

fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(imgBalik)
# plt.imshow(imgBalik)

# %%
import numpy as np
import cv2


black_img = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img)

# cv2.rectangle(black_img,pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
# cv2.rectangle(black_img,pt1=(200,200), pt2=(300,300), color=(0,0,255),thickness=15)
# cv2.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
# cv2.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
# font = cv2.FONT_HERSHEY_SIMPLEX
# cv2.putText(black_img, text="Hello", org=(10,500), fontFace=font,fontScale=4, color=(255,255,0), thickness=2, lineType=cv2.LINE_AA)
# plt.imshow(black_img)

vertices = np.array([[100,300], [200,200],[400,300],[200,400]], dtype=np.int32)
vertices
pts = vertices.reshape((-1,1,2))
pts

cv2.polylines(black_img, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img)
